# %%
import numpy as np

A = np.array([[1, 2, 4], [7, 5, -2], [-2, 1, 3]])
B = np.array([[-1, 0, 3], [2, -6, 1], [-7, 1, 5]])
C = np.array([[-2, 3], [4, 0], [7, -1]])

# %%
A + B
# Out:
# array([[ 0,  2,  7],
#        [ 9, -1, -1],
#        [-9,  2,  8]])

# %%
B - A
# Out:
# array([[ -2,  -2,  -1],
#        [ -5, -11,   3],
#        [ -5,   0,   2]])

# %%
np.dot(A,C)
# Out:
# array([[34, -1],
#        [-8, 23],
#        [29, -9]])

# %%
np.dot(np.dot(A,B),C)
# Out:
# array([[ 193, -100],
#        [ -50,   35],
#        [  92,  -61]])

# %%
A = np.array([[9, 2, 4], [7, 5, -5], [6, -2, 3]])
B = np.array([[8, 2, 4], [0, 1, -3], [-2, 1, 6]])
C = np.array([[-2, 0], [4, 8], [1, -1]])

# %%
import matplotlib.pyplot as plt
import cv2
img = cv2.imread('cat.jpeg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
window_name = 'Image'
ksize = (3, 3) 
image = cv2.blur(img_rgb, ksize)
plt.imshow(image)

# %%
plt.imshow(img_rgb)

# %%
blur_img = img.copy()
blur_img
# Out:
# array([[[ 50, 109, 189],
#         [ 51, 110, 190],
#         [ 50, 111, 191],
#         ...,
#         [ 56, 105, 181],
#         [ 58, 105, 179],
#         [ 58, 105, 179]],
#
#        [[ 50, 109, 189],
#         [ 51, 110, 190],
#         [ 51, 112, 192],
#         ...,
#         [ 56, 105, 181],
#         [ 58, 105, 179],
#         [ 58, 105, 179]],
#
#        [[ 51, 110, 190],
#         [ 52, 111, 191],
#         [ 52, 113, 193],
#         ...,
#         [ 57, 106, 182],
#         [ 59, 106, 180],
#         [ 59, 106, 180]],
#
#        ...,
#
#        [[ 37,  92, 173],
#         [ 38,  93, 174],
#         [ 39,  94, 175],
#         ...,
#         [ 37,  82, 155],
#         [ 37,  82, 155],
#         [ 37,  82, 155]],
#
#        [[ 36,  91, 172],
#         [ 37,  92, 173],
#         [ 38,  93, 174],
#         ...,
#         [ 36,  81, 154],
#         [ 36,  81, 154],
#         [ 35,  80, 153]],
#
#        [[ 35,  90, 171],
#         [ 36,  91, 172],
#         [ 37,  92, 173],
#         ...,
#         [ 35,  80, 153],
#         [ 35,  80, 153],
#         [ 34,  79, 152]]], dtype=uint8)

# %%
blur_img.shape
# Out:
# (183, 275, 3)
